# %%
import os
from google.colab import drive 
drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/AI')
# Out:
# Mounted at /content/drive

# %%
from keras import datasets, Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, Dropout, LayerNormalization
from keras.preprocessing import  image
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from numpy import asarray
from numpy import save
import keras
from os import listdir
import cv2 as cv
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split

# %%
folder0 = 'Age/18'
folder1 ='Age/19'
folder2 = 'Age/20'
folder3 = 'Age/21'
folder4 = 'Age/22'
folder5 = 'Age/23'
folder6 = 'Age/24'
folder7 = 'Age/25'
folder8 = 'Age/26'
folder9 = 'Age/27'
folders=[folder0,folder1,folder2,folder3,folder4,folder5,folder6,folder7,folder8,folder9]
photos, labels = list(), list()
for i in range (10):
  for file in listdir(folders[i]):
    output=i
    photo = load_img(folders[i]+'/'+file, target_size=(128,128))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)
save('Age/age_photos.npy',photos)
save('Age/age_labels.npy',labels)
# Out:
# (6000, 128, 128, 3) (6000,)

# %%
x_train, x_test, y_train, y_test = train_test_split(photos, labels, test_size=0.3, random_state=2)

# %%
x_train /= 255
x_test /= 255
y_train = keras.utils.np_utils.to_categorical(y_train)
y_test = keras.utils.np_utils.to_categorical(y_test)

# %%
"""# Age Model
we define the Cnn model here, we are using a sequential model ie data will travel sequentially from one layer to another without any jumps and splitting.
"""
model = Sequential()
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same',input_shape=(128,128,3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(512,(3,3), activation = 'relu', kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_initializer='he_uniform'))  #Dense la full connected 
model.add(Dense(10, activation='softmax')) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 512)       590336
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 512)               16777728
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 17,466,442
# Trainable params: 17,466,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = SGD(lr=0.01, momentum=0.9)
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(optimizer=opt,loss='categorical_crossentropy',  metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=32, epochs=100, verbose=1,validation_data=(x_test, y_test), callbacks=[callback])
model.save('age_model.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/100
# 132/132 [==============================] - 17s 36ms/step - loss: 2.3899 - accuracy: 0.0981 - val_loss: 2.3030 - val_accuracy: 0.1044
# Epoch 2/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.3003 - accuracy: 0.1057 - val_loss: 2.3024 - val_accuracy: 0.1106
# Epoch 3/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.2944 - accuracy: 0.1186 - val_loss: 2.3020 - val_accuracy: 0.1144
# Epoch 4/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.2846 - accuracy: 0.1348 - val_loss: 2.3034 - val_accuracy: 0.1222
# Epoch 5/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.2680 - accuracy: 0.1450 - val_loss: 2.3035 - val_accuracy: 0.1206
# Epoch 6/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.2408 - accuracy: 0.1629 - val_loss: 2.3116 - val_accuracy: 0.1350
# Epoch 7/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.2119 - accuracy: 0.1838 - val_loss: 2.3093 - val_accuracy: 0.1450
# Epoch 8/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.1463 - accuracy: 0.2095 - val_loss: 2.3329 - val_accuracy: 0.1367
# Epoch 9/100
# 132/132 [==============================] - 4s 30ms/step - loss: 2.0467 - accuracy: 0.2679 - val_loss: 2.3887 - val_accuracy: 0.1378
# Epoch 10/100
# 132/132 [==============================] - 4s 32ms/step - loss: 1.8739 - accuracy: 0.3438 - val_loss: 2.5305 - val_accuracy: 0.1350
# Epoch 11/100
# 132/132 [==============================] - 4s 30ms/step - loss: 1.6223 - accuracy: 0.4438 - val_loss: 2.5848 - val_accuracy: 0.1422
# Epoch 12/100
# 132/132 [==============================] - 4s 30ms/step - loss: 1.2826 - accuracy: 0.5712 - val_loss: 2.9165 - val_accuracy: 0.1233
# Epoch 13/100
# 132/132 [==============================] - 4s 31ms/step - loss: 1.0413 - accuracy: 0.6521 - val_loss: 3.2010 - val_accuracy: 0.1394
# Epoch 14/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.7251 - accuracy: 0.7638 - val_loss: 4.2430 - val_accuracy: 0.1161
# Epoch 15/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.5616 - accuracy: 0.8248 - val_loss: 4.6354 - val_accuracy: 0.1389
# Epoch 16/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.4414 - accuracy: 0.8648 - val_loss: 5.1369 - val_accuracy: 0.1333
# Epoch 17/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.3580 - accuracy: 0.8960 - val_loss: 4.7311 - val_accuracy: 0.1433
# Epoch 18/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.2646 - accuracy: 0.9233 - val_loss: 5.4092 - val_accuracy: 0.1256
# Epoch 19/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1748 - accuracy: 0.9526 - val_loss: 6.0922 - val_accuracy: 0.1383
# Epoch 20/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1709 - accuracy: 0.9526 - val_loss: 5.8570 - val_accuracy: 0.1372
# Epoch 21/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1793 - accuracy: 0.9543 - val_loss: 6.3357 - val_accuracy: 0.1317
# Epoch 22/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0693 - accuracy: 0.9867 - val_loss: 6.3034 - val_accuracy: 0.1322
# Epoch 23/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0315 - accuracy: 0.9955 - val_loss: 6.3610 - val_accuracy: 0.1361
# Epoch 24/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0224 - accuracy: 0.9967 - val_loss: 6.4533 - val_accuracy: 0.1444
# Epoch 25/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0180 - accuracy: 0.9962 - val_loss: 6.3053 - val_accuracy: 0.1333
# Epoch 26/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0135 - accuracy: 0.9971 - val_loss: 6.0330 - val_accuracy: 0.1339
# Epoch 27/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 6.1436 - val_accuracy: 0.1461
# Epoch 28/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 6.1056 - val_accuracy: 0.1367
# Epoch 29/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 6.3010 - val_accuracy: 0.1411
# Epoch 30/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 6.4865 - val_accuracy: 0.1417
# Epoch 31/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 6.3754 - val_accuracy: 0.1411
# Epoch 32/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 6.1805 - val_accuracy: 0.1456
# Epoch 33/100
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 6.2582 - val_accuracy: 0.1439

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.show()

# %%
from keras.preprocessing.image   import load_img
from keras.preprocessing.image  import img_to_array
from keras.models               import load_model
import numpy as np
import matplotlib.pyplot as plt

img = load_img('Age/test.jpg', target_size=(128,128))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 128,128, 3)
img = img.astype('float32')
img = img / 255.0

# load model
model = load_model('Age/age_model.h5')
# predict the class
result = model.predict(img)
print('Giá trị dự đoán:', np.argmax(result))
plt.show()
# Out:
# Giá trị dự đoán: 5

# %%
from keras.preprocessing.image   import load_img
from keras.preprocessing.image  import img_to_array
from keras.models               import load_model
import numpy as np
import matplotlib.pyplot as plt

img = load_img('Age/test1.jpg', target_size=(128,128))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 128,128, 3)
img = img.astype('float32')
img = img / 255.0

# load model
model = load_model('Age/age_model.h5')
# predict the class
result = model.predict(img)
print('Giá trị dự đoán:', np.argmax(result))
plt.show()
# Out:
# Giá trị dự đoán: 2
